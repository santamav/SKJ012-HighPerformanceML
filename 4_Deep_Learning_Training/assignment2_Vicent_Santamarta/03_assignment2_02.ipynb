# %% [markdown]
# **Please note that the 01_setup notebook should be executed before running this notebook**

# %%
import os, textwrap
from icecream import ic
# Get original notebook path and LD_LIBRARY_PATH
notebook_path = ic(os.getcwd())
original_ld_library_path = ic(os.environ.get('LD_LIBRARY_PATH'))
# Software and install_prefix as defined in 01_setup.ipynb
software_path = ic(os.path.join(notebook_path, 'sjk012', 'software'))
install_prefix = ic(os.path.join(software_path, 'opt'))
# Out:
# ic| os.getcwd(): ('/home/vicentamen/Documents/Intelligent '
#                   'Systems/SKJ012-HighPerformanceML/4_Deep_Learning_Training/assignment2')
# ic| os.environ.get('LD_LIBRARY_PATH'): (':/home/vicentamen/Documents/Intelligent '
#                                         'Systems/SKJ012-HighPerformanceML/4_Deep_Learning_Training/assignment2/sjk012/software/OpenBLAS')
# ic| os.path.join(notebook_path, 'sjk012', 'software'): ('/home/vicentamen/Documents/Intelligent '
#                                                         'Systems/SKJ012-HighPerformanceML/4_Deep_Learning_Training/assignment2/sjk012/software')
# ic| os.path.join(software_path, 'opt'): ('/home/vicentamen/Documents/Intelligent '
#                                          'Systems/SKJ012-HighPerformanceML/4_Deep_Learning_Training/assignment2/sjk012/software/opt')

# %%
# Update the environment
os.environ['LD_LIBRARY_PATH'] = os.path.join(install_prefix, 'blis', 'lib')
os.environ['LD_LIBRARY_PATH'] += ":"
os.environ['LD_LIBRARY_PATH'] += os.path.join(install_prefix, 'openblas', 'lib')
if original_ld_library_path is not None:
    os.environ['LD_LIBRARY_PATH'] += ":"
    os.environ['LD_LIBRARY_PATH'] += original_ld_library_path
_ = ic(os.environ['LD_LIBRARY_PATH'])
# Out:
# ic| os.environ['LD_LIBRARY_PATH']: ('/home/vicentamen/Documents/Intelligent '
#                                     'Systems/SKJ012-HighPerformanceML/4_Deep_Learning_Training/assignment2/sjk012/software/opt/blis/lib:/home/vicentamen/Documents/Intelligent '
#                                     'Systems/SKJ012-HighPerformanceML/4_Deep_Learning_Training/assignment2/sjk012/software/opt/openblas/lib::/home/vicentamen/Documents/Intelligent '
#                                     'Systems/SKJ012-HighPerformanceML/4_Deep_Learning_Training/assignment2/sjk012/software/OpenBLAS')

# %%
# Setup cell
import numpy as np
import matplotlib.pyplot as plt
from sjk012.classifiers.cnn import *
from sjk012.data_utils import get_CIFAR10_data
from sjk012.gradient_check import eval_numerical_gradient_array, eval_numerical_gradient
from sjk012.layers import *
# from sjk012.fast_layers import *
from sjk012.solver import Solver

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# Use pyximport to compile the cython modules
import pyximport
pyximport.install(reload_support=True, pyimport=True)

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
# Load the (preprocessed) CIFAR-10 data.
data = get_CIFAR10_data()
for k, v in list(data.items()):
    print(f"{k}: {v.shape}")
# Out:
# X_train: (49000, 3, 32, 32)
# y_train: (49000,)
# X_val: (1000, 3, 32, 32)
# y_val: (1000,)
# X_test: (1000, 3, 32, 32)
# y_test: (1000,)

# %% [markdown]
# # Convolutional "Sandwich" Layers
# In the previous assignment, we introduced the concept of "sandwich" layers that combine multiple operations into commonly used patterns. In the file `sjk012/layer_utils.py` you will find sandwich layers that implement a few commonly used patterns for convolutional networks. Run the cells below to sanity check their usage.

# %%
from sjk012.layer_utils import conv_relu_pool_forward, conv_relu_pool_backward
from sjk012.gradient_check import *
np.random.seed(12)
x = np.random.randn(2, 3, 8, 8).astype(np.float32)
w = np.random.randn(3, 3, 3, 3).astype(np.float32)
b = np.random.randn(3,).astype(np.float32)
dy = np.random.randn(2, 3, 4, 4).astype(np.float32)
conv_param = {'stride': 1, 'pad': 1}
pool_param = {'pool_height': 2, 'pool_width': 2, 'stride': 2, 'padding': 0}

y, cache = conv_relu_pool_forward(x, w, b, conv_param, pool_param)
dx, dw, db = conv_relu_pool_backward(dy, cache)

dx_num = eval_numerical_gradient_array(lambda x: conv_relu_pool_forward(x, w, b, conv_param, pool_param)[0], x, dy, h=1e-3)
dw_num = eval_numerical_gradient_array(lambda w: conv_relu_pool_forward(x, w, b, conv_param, pool_param)[0], w, dy, h=1e-3)
db_num = eval_numerical_gradient_array(lambda b: conv_relu_pool_forward(x, w, b, conv_param, pool_param)[0], b, dy, h=1e-3)

# Relative errors should be around e-8 or less
print('Testing conv_relu_pool')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing conv_relu_pool
# dx error:  0.03132247
# dw error:  0.0025086026
# db error:  5.0166473e-05

# %%
a, conv_cache = conv_forward_cython(x, w, b, conv_param)
out, relu_cache = relu_forward_cython(a)

# %% [markdown]
# # Three-Layer Convolutional Network
# Now that you have implemented all the necessary layers, we can put them together into a simple convolutional network.
#
# Open the file `sjk012/classifiers/cnn.py` and complete the implementation of the `ThreeLayerConvNet` class. Remember you can use the fast/sandwich layers (already imported for you) in your implementation. Run the following cells to help you debug:

# %% [markdown]
# ## Sanity Check Loss
# After you build a new network, one of the first things you should do is sanity check the loss. When we use the softmax loss, we expect the loss for random weights (and no regularization) to be about `log(C)` for `C` classes. When we add regularization the loss should go up slightly.

# %%
model = ThreeLayerConvNet()

N = 50
X = np.random.randn(N, 3, 32, 32).astype(np.float32)
y = np.random.randint(10, size=N).astype(np.int8)

loss, grads = model.loss(X, y)
print('Initial loss (no regularization): ', loss)

model.reg = 0.5
loss, grads = model.loss(X, y)
print('Initial loss (with regularization): ', loss)
# Out:
# Initial loss (no regularization):  2.3025859069824217
# Initial loss (with regularization):  2.5087668669223784

# %% [markdown]
# ## Gradient Check
# After the loss looks reasonable, use numeric gradient checking to make sure that your backward pass is correct. When you use numeric gradient checking you should use a small amount of artificial data and a small number of neurons at each layer. Note: correct implementations may still have relative errors up to the order of e-2.

# %%
num_inputs = 2
input_dim = (3, 8, 8)
reg = 0.0
num_classes = 10
np.random.seed(12)
X = np.random.randn(num_inputs, *input_dim).astype(np.float32)
y = np.random.randint(num_classes, size=num_inputs).astype(np.int8)

model = ThreeLayerConvNet(
    num_filters=3,
    filter_size=3,
    input_dim=input_dim,
    hidden_dim=5,
    dtype=np.float32
)
loss, grads = model.loss(X, y)
# Errors should be small, but correct implementations may have
# relative errors up to the order of e-2
for param_name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    param_grad_num = eval_numerical_gradient(f, model.params[param_name], verbose=False, h=1e-0)
    e = rel_error(param_grad_num, grads[param_name])
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])), 'Allclose: ', np.allclose(param_grad_num, grads[param_name], atol=1e-2))
# Out:
# W1 max relative error: 1.000000e+00 Allclose:  True
# W2 max relative error: 1.000000e+00 Allclose:  True
# W3 max relative error: 1.862457e-01 Allclose:  True
# b1 max relative error: 1.000000e+00 Allclose:  True
# b2 max relative error: 1.000000e+00 Allclose:  True
# b3 max relative error: 5.630022e-02 Allclose:  False

# %% [markdown]
# ## Overfit Small Data
# A nice trick is to train your model with just a few training samples. You should be able to overfit small datasets, which will result in very high training accuracy and comparatively low validation accuracy.

# %%
np.random.seed(12)

num_train = 100
small_data = {
  'X_train': data['X_train'][:num_train].astype(np.float32),
  'y_train': data['y_train'][:num_train].astype(np.int8),
  'X_val': data['X_val'].astype(np.float32),
  'y_val': data['y_val'].astype(np.int8),
}

model = ThreeLayerConvNet(dtype=np.float32)

solver = Solver(
    model,
    small_data,
    num_epochs=20,
    batch_size=50,
    update_rule='adam',
    optim_config={'learning_rate': 1e-3,},
    verbose=True,
    print_every=1
)
solver.train()
# Out:
# (Iteration 1 / 40) loss: 2.302594
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.119000
# (Iteration 2 / 40) loss: 2.280381
# (Epoch 1 / 20) train acc: 0.240000; val_acc: 0.135000
# (Iteration 3 / 40) loss: 2.260540
# (Iteration 4 / 40) loss: 2.174955
# (Epoch 2 / 20) train acc: 0.330000; val_acc: 0.151000
# (Iteration 5 / 40) loss: 1.965284
# (Iteration 6 / 40) loss: 2.281383
# (Epoch 3 / 20) train acc: 0.230000; val_acc: 0.149000
# (Iteration 7 / 40) loss: 2.000278
# (Iteration 8 / 40) loss: 1.973747
# (Epoch 4 / 20) train acc: 0.300000; val_acc: 0.161000
# (Iteration 9 / 40) loss: 1.909455
# (Iteration 10 / 40) loss: 1.773627
# (Epoch 5 / 20) train acc: 0.340000; val_acc: 0.166000
# (Iteration 11 / 40) loss: 1.633253
# (Iteration 12 / 40) loss: 1.625745
# (Epoch 6 / 20) train acc: 0.410000; val_acc: 0.183000
# (Iteration 13 / 40) loss: 1.370309
# (Iteration 14 / 40) loss: 1.695502
# (Epoch 7 / 20) train acc: 0.500000; val_acc: 0.172000
# (Iteration 15 / 40) loss: 1.235601
# (Iteration 16 / 40) loss: 1.488160
# (Epoch 8 / 20) train acc: 0.590000; val_acc: 0.161000
# (Iteration 17 / 40) loss: 1.299381
# (Iteration 18 / 40) loss: 1.105366
# (Epoch 9 / 20) train acc: 0.690000; val_acc: 0.203000
# (Iteration 19 / 40) loss: 0.871249
# (Iteration 20 / 40) loss: 1.143208
# (Epoch 10 / 20) train acc: 0.720000; val_acc: 0.206000
# (Iteration 21 / 40) loss: 0.796927
# (Iteration 22 / 40) loss: 0.876585
# (Epoch 11 / 20) train acc: 0.790000; val_acc: 0.191000
# (Iteration 23 / 40) loss: 0.596185
# (Iteration 24 / 40) loss: 0.413492
# (Epoch 12 / 20) train acc: 0.900000; val_acc: 0.214000
# (Iteration 25 / 40) loss: 0.438747
# (Iteration 26 / 40) loss: 0.296874
# (Epoch 13 / 20) train acc: 0.920000; val_acc: 0.209000
# (Iteration 27 / 40) loss: 0.354930
# (Iteration 28 / 40) loss: 0.281447
# (Epoch 14 / 20) train acc: 0.920000; val_acc: 0.214000
# (Iteration 29 / 40) loss: 0.257322
# (Iteration 30 / 40) loss: 0.106184
# (Epoch 15 / 20) train acc: 0.960000; val_acc: 0.196000
# (Iteration 31 / 40) loss: 0.182457
# (Iteration 32 / 40) loss: 0.180511
# (Epoch 16 / 20) train acc: 0.950000; val_acc: 0.195000
# (Iteration 33 / 40) loss: 0.085601
# (Iteration 34 / 40) loss: 0.192785
# (Epoch 17 / 20) train acc: 0.970000; val_acc: 0.203000
# (Iteration 35 / 40) loss: 0.048396
# (Iteration 36 / 40) loss: 0.108008
# (Epoch 18 / 20) train acc: 0.920000; val_acc: 0.196000
# (Iteration 37 / 40) loss: 0.108515
# (Iteration 38 / 40) loss: 0.151638
# (Epoch 19 / 20) train acc: 0.980000; val_acc: 0.199000
# (Iteration 39 / 40) loss: 0.088178
# (Iteration 40 / 40) loss: 0.406256
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.200000

# %%
# Print final training accuracy.
print(
    "Small data training accuracy:",
    solver.check_accuracy(small_data['X_train'], small_data['y_train'])
)
# Out:
# Small data training accuracy: 0.9

# %%
# Print final validation accuracy.
print(
    "Small data validation accuracy:",
    solver.check_accuracy(small_data['X_val'], small_data['y_val'])
)
# Out:
# Small data validation accuracy: 0.214

# %% [markdown]
# Plotting the loss, training accuracy, and validation accuracy should show clear overfitting:

# %%
plt.subplot(2, 1, 1)
plt.plot(solver.loss_history, 'o')
plt.xlabel('iteration')
plt.ylabel('loss')

plt.subplot(2, 1, 2)
plt.plot(solver.train_acc_history, '-o')
plt.plot(solver.val_acc_history, '-o')
plt.legend(['train', 'val'], loc='upper left')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %% [markdown]
# ## Parallel Performance Evaluation: Analyzing Training Time with Different Number of Threads and Batch Sizes
#
# In this exercise, you will explore how the training time of a convolutional neural network (CNN) model varies with different numbers of threads and batch sizes. You will use the provided training code to train the model and measure the training time for various configurations.
#
# ### Instructions:
#
# 1. Load the provided dataset (`data`) and ensure it contains the necessary training and validation data.
# 2. Implement the `train_model` function to train the CNN model using the specified number of threads and batch size. Use the provided training code as a reference.
# 3. Set the right batch size to the solver (`batch_size`) to test.
# 4. Measure the training time of the `train_model` function.

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from threadpoolctl import threadpool_limits

# Define the training code
def train_model(batch_size):
    np.random.seed(12)

    ###########################################################################
    # TODO: Call the train model method and measure its training time         #
    ###########################################################################
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    num_train = 100
    small_data = {
    'X_train': data['X_train'][:num_train].astype(np.float32),
    'y_train': data['y_train'][:num_train].astype(np.int8),
    'X_val': data['X_val'].astype(np.float32),
    'y_val': data['y_val'].astype(np.int8),
    }

    model = ThreeLayerConvNet(dtype=np.float32)

    solver = Solver(
        model,
        small_data,
        num_epochs=20,
        batch_size=batch_size,
        update_rule='adam',
        optim_config={'learning_rate': 1e-3,},
        verbose=True,
        print_every=1
    )
    
    start_time = time.time()
    solver.train()
    end_time = time.time()
    # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    ###########################################################################
    #                             END OF YOUR CODE                            #
    ###########################################################################    
    
    return end_time - start_time

# Define the number of threads and batch size configurations to test
num_threads_list = [1, 4, 8, 16]
batch_size_list = [16, 32, 64]

# Measure the training time for each configuration
training_times = np.zeros((len(num_threads_list), len(batch_size_list)))

for i, n_threads in enumerate(num_threads_list):
    with threadpool_limits(limits=n_threads):
        for j, batch_size in enumerate(batch_size_list):
            print('Testing training with %d threads and %d batch size' %(n_threads, batch_size))
            training_time = train_model(batch_size)
            training_times[i, j] = training_time
# Out:
# Testing training with 1 threads and 16 batch size
# (Iteration 1 / 120) loss: 2.302579
# (Epoch 0 / 20) train acc: 0.060000; val_acc: 0.087000
# (Iteration 2 / 120) loss: 2.398489
# (Iteration 3 / 120) loss: 2.311533
# (Iteration 4 / 120) loss: 2.244668
# (Iteration 5 / 120) loss: 2.209500
# (Iteration 6 / 120) loss: 2.346014
# (Epoch 1 / 20) train acc: 0.170000; val_acc: 0.132000
# (Iteration 7 / 120) loss: 2.132516
# (Iteration 8 / 120) loss: 2.377617
# (Iteration 9 / 120) loss: 2.380939
# (Iteration 10 / 120) loss: 2.257062
# (Iteration 11 / 120) loss: 2.280143
# (Iteration 12 / 120) loss: 2.374243
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.100000
# (Iteration 13 / 120) loss: 2.261114
# (Iteration 14 / 120) loss: 2.268343
# (Iteration 15 / 120) loss: 2.200629
# (Iteration 16 / 120) loss: 2.343858
# (Iteration 17 / 120) loss: 2.060695
# (Iteration 18 / 120) loss: 2.295088
# (Epoch 3 / 20) train acc: 0.240000; val_acc: 0.144000
# (Iteration 19 / 120) loss: 2.122414
# (Iteration 20 / 120) loss: 1.853972
# (Iteration 21 / 120) loss: 2.252908
# (Iteration 22 / 120) loss: 1.732632
# (Iteration 23 / 120) loss: 1.763082
# (Iteration 24 / 120) loss: 2.290329
# (Epoch 4 / 20) train acc: 0.310000; val_acc: 0.157000
# (Iteration 25 / 120) loss: 2.209058
# (Iteration 26 / 120) loss: 2.419957
# (Iteration 27 / 120) loss: 1.769374
# (Iteration 28 / 120) loss: 1.719631
# (Iteration 29 / 120) loss: 2.024216
# (Iteration 30 / 120) loss: 1.790543
# (Epoch 5 / 20) train acc: 0.320000; val_acc: 0.160000
# (Iteration 31 / 120) loss: 1.663693
# (Iteration 32 / 120) loss: 2.225198
# (Iteration 33 / 120) loss: 1.738102
# (Iteration 34 / 120) loss: 1.602698
# (Iteration 35 / 120) loss: 2.070795
# (Iteration 36 / 120) loss: 1.276247
# (Epoch 6 / 20) train acc: 0.380000; val_acc: 0.190000
# (Iteration 37 / 120) loss: 1.717255
# (Iteration 38 / 120) loss: 1.305076
# (Iteration 39 / 120) loss: 1.535748
# (Iteration 40 / 120) loss: 1.154556
# (Iteration 41 / 120) loss: 1.966010
# (Iteration 42 / 120) loss: 1.224132
# (Epoch 7 / 20) train acc: 0.430000; val_acc: 0.193000
# (Iteration 43 / 120) loss: 1.809401
# (Iteration 44 / 120) loss: 1.479795
# (Iteration 45 / 120) loss: 1.271581
# (Iteration 46 / 120) loss: 1.654023
# (Iteration 47 / 120) loss: 1.972132
# (Iteration 48 / 120) loss: 1.451545
# (Epoch 8 / 20) train acc: 0.490000; val_acc: 0.142000
# (Iteration 49 / 120) loss: 1.793844
# (Iteration 50 / 120) loss: 1.531180
# (Iteration 51 / 120) loss: 1.932110
# (Iteration 52 / 120) loss: 2.079466
# (Iteration 53 / 120) loss: 1.740865
# (Iteration 54 / 120) loss: 1.452860
# (Epoch 9 / 20) train acc: 0.440000; val_acc: 0.146000
# (Iteration 55 / 120) loss: 1.396486
# (Iteration 56 / 120) loss: 1.342266
# (Iteration 57 / 120) loss: 1.551614
# (Iteration 58 / 120) loss: 1.277057
# (Iteration 59 / 120) loss: 1.264424
# (Iteration 60 / 120) loss: 1.086302
# (Epoch 10 / 20) train acc: 0.430000; val_acc: 0.169000
# (Iteration 61 / 120) loss: 2.268901
# (Iteration 62 / 120) loss: 1.170291
# (Iteration 63 / 120) loss: 1.380536
# (Iteration 64 / 120) loss: 0.884503
# (Iteration 65 / 120) loss: 1.354563
# (Iteration 66 / 120) loss: 1.373986
# (Epoch 11 / 20) train acc: 0.570000; val_acc: 0.154000
# (Iteration 67 / 120) loss: 1.244381
# (Iteration 68 / 120) loss: 1.088170
# (Iteration 69 / 120) loss: 0.892631
# (Iteration 70 / 120) loss: 1.378647
# (Iteration 71 / 120) loss: 0.813176
# (Iteration 72 / 120) loss: 1.091570
# (Epoch 12 / 20) train acc: 0.620000; val_acc: 0.166000
# (Iteration 73 / 120) loss: 0.844725
# (Iteration 74 / 120) loss: 0.605134
# (Iteration 75 / 120) loss: 0.984451
# (Iteration 76 / 120) loss: 0.596746
# (Iteration 77 / 120) loss: 1.187185
# (Iteration 78 / 120) loss: 1.380489
# (Epoch 13 / 20) train acc: 0.610000; val_acc: 0.166000
# (Iteration 79 / 120) loss: 1.337092
# (Iteration 80 / 120) loss: 0.932493
# (Iteration 81 / 120) loss: 0.848889
# (Iteration 82 / 120) loss: 0.776160
# (Iteration 83 / 120) loss: 1.055342
# (Iteration 84 / 120) loss: 0.706417
# (Epoch 14 / 20) train acc: 0.690000; val_acc: 0.197000
# (Iteration 85 / 120) loss: 1.220455
# (Iteration 86 / 120) loss: 0.440119
# (Iteration 87 / 120) loss: 0.656866
# (Iteration 88 / 120) loss: 0.725722
# (Iteration 89 / 120) loss: 1.041019
# (Iteration 90 / 120) loss: 0.584394
# (Epoch 15 / 20) train acc: 0.760000; val_acc: 0.179000
# (Iteration 91 / 120) loss: 0.405660
# (Iteration 92 / 120) loss: 0.635248
# (Iteration 93 / 120) loss: 0.680659
# (Iteration 94 / 120) loss: 0.452574
# (Iteration 95 / 120) loss: 0.391136
# (Iteration 96 / 120) loss: 0.741392
# (Epoch 16 / 20) train acc: 0.740000; val_acc: 0.178000
# (Iteration 97 / 120) loss: 0.686821
# (Iteration 98 / 120) loss: 0.393391
# (Iteration 99 / 120) loss: 0.929713
# (Iteration 100 / 120) loss: 0.765333
# (Iteration 101 / 120) loss: 0.886702
# (Iteration 102 / 120) loss: 0.797742
# (Epoch 17 / 20) train acc: 0.740000; val_acc: 0.154000
# (Iteration 103 / 120) loss: 0.240939
# (Iteration 104 / 120) loss: 0.465094
# (Iteration 105 / 120) loss: 0.873907
# (Iteration 106 / 120) loss: 0.979055
# (Iteration 107 / 120) loss: 0.507225
# (Iteration 108 / 120) loss: 0.446307
# (Epoch 18 / 20) train acc: 0.700000; val_acc: 0.158000
# (Iteration 109 / 120) loss: 1.225797
# (Iteration 110 / 120) loss: 0.480374
# (Iteration 111 / 120) loss: 0.602384
# (Iteration 112 / 120) loss: 0.554726
# (Iteration 113 / 120) loss: 0.492822
# (Iteration 114 / 120) loss: 0.853161
# (Epoch 19 / 20) train acc: 0.710000; val_acc: 0.182000
# (Iteration 115 / 120) loss: 0.422985
# (Iteration 116 / 120) loss: 0.463718
# (Iteration 117 / 120) loss: 0.981309
# (Iteration 118 / 120) loss: 0.464277
# (Iteration 119 / 120) loss: 1.050937
# (Iteration 120 / 120) loss: 0.409434
# (Epoch 20 / 20) train acc: 0.770000; val_acc: 0.183000
# Testing training with 1 threads and 32 batch size
# (Iteration 1 / 60) loss: 2.302598
# (Epoch 0 / 20) train acc: 0.110000; val_acc: 0.121000
# (Iteration 2 / 60) loss: 2.350591
# (Iteration 3 / 60) loss: 2.191995
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.098000
# (Iteration 4 / 60) loss: 2.386932
# (Iteration 5 / 60) loss: 2.210626
# (Iteration 6 / 60) loss: 2.208829
# (Epoch 2 / 20) train acc: 0.270000; val_acc: 0.153000
# (Iteration 7 / 60) loss: 2.031611
# (Iteration 8 / 60) loss: 2.180714
# (Iteration 9 / 60) loss: 1.978459
# (Epoch 3 / 20) train acc: 0.290000; val_acc: 0.153000
# (Iteration 10 / 60) loss: 1.933452
# (Iteration 11 / 60) loss: 2.009228
# (Iteration 12 / 60) loss: 1.973597
# (Epoch 4 / 20) train acc: 0.330000; val_acc: 0.171000
# (Iteration 13 / 60) loss: 1.868188
# (Iteration 14 / 60) loss: 1.617899
# (Iteration 15 / 60) loss: 1.736994
# (Epoch 5 / 20) train acc: 0.370000; val_acc: 0.182000
# (Iteration 16 / 60) loss: 1.502582
# (Iteration 17 / 60) loss: 1.454178
# (Iteration 18 / 60) loss: 1.683645
# (Epoch 6 / 20) train acc: 0.440000; val_acc: 0.169000
# (Iteration 19 / 60) loss: 1.451940
# (Iteration 20 / 60) loss: 1.147163
# (Iteration 21 / 60) loss: 1.151501
# (Epoch 7 / 20) train acc: 0.570000; val_acc: 0.187000
# (Iteration 22 / 60) loss: 1.211664
# (Iteration 23 / 60) loss: 1.097508
# (Iteration 24 / 60) loss: 1.086754
# (Epoch 8 / 20) train acc: 0.700000; val_acc: 0.183000
# (Iteration 25 / 60) loss: 1.311142
# (Iteration 26 / 60) loss: 0.915283
# (Iteration 27 / 60) loss: 0.950469
# (Epoch 9 / 20) train acc: 0.750000; val_acc: 0.195000
# (Iteration 28 / 60) loss: 0.493129
# (Iteration 29 / 60) loss: 0.660182
# (Iteration 30 / 60) loss: 0.660265
# (Epoch 10 / 20) train acc: 0.790000; val_acc: 0.193000
# (Iteration 31 / 60) loss: 0.650539
# (Iteration 32 / 60) loss: 0.351387
# (Iteration 33 / 60) loss: 0.360971
# (Epoch 11 / 20) train acc: 0.890000; val_acc: 0.192000
# (Iteration 34 / 60) loss: 0.272677
# (Iteration 35 / 60) loss: 0.737071
# (Iteration 36 / 60) loss: 0.310238
# (Epoch 12 / 20) train acc: 0.890000; val_acc: 0.205000
# (Iteration 37 / 60) loss: 0.250067
# (Iteration 38 / 60) loss: 0.217762
# (Iteration 39 / 60) loss: 0.390952
# (Epoch 13 / 20) train acc: 0.950000; val_acc: 0.212000
# (Iteration 40 / 60) loss: 0.170185
# (Iteration 41 / 60) loss: 0.410323
# (Iteration 42 / 60) loss: 0.350137
# (Epoch 14 / 20) train acc: 0.950000; val_acc: 0.205000
# (Iteration 43 / 60) loss: 0.157851
# (Iteration 44 / 60) loss: 0.243549
# (Iteration 45 / 60) loss: 0.727606
# (Epoch 15 / 20) train acc: 0.910000; val_acc: 0.210000
# (Iteration 46 / 60) loss: 0.161584
# (Iteration 47 / 60) loss: 0.376359
# (Iteration 48 / 60) loss: 0.139338
# (Epoch 16 / 20) train acc: 0.970000; val_acc: 0.225000
# (Iteration 49 / 60) loss: 0.233488
# (Iteration 50 / 60) loss: 0.091358
# (Iteration 51 / 60) loss: 0.057077
# (Epoch 17 / 20) train acc: 0.970000; val_acc: 0.195000
# (Iteration 52 / 60) loss: 0.073686
# (Iteration 53 / 60) loss: 0.462756
# (Iteration 54 / 60) loss: 0.055458
# (Epoch 18 / 20) train acc: 0.980000; val_acc: 0.183000
# (Iteration 55 / 60) loss: 0.089258
# (Iteration 56 / 60) loss: 0.216676
# (Iteration 57 / 60) loss: 0.259092
# (Epoch 19 / 20) train acc: 0.970000; val_acc: 0.188000
# (Iteration 58 / 60) loss: 0.045076
# (Iteration 59 / 60) loss: 0.157602
# (Iteration 60 / 60) loss: 0.114999
# (Epoch 20 / 20) train acc: 0.970000; val_acc: 0.206000
# Testing training with 1 threads and 64 batch size
# (Iteration 1 / 20) loss: 2.302606
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.119000
# (Iteration 2 / 20) loss: 2.293767
# (Epoch 2 / 20) train acc: 0.220000; val_acc: 0.130000
# (Iteration 3 / 20) loss: 2.212615
# (Epoch 3 / 20) train acc: 0.220000; val_acc: 0.139000
# (Iteration 4 / 20) loss: 2.120204
# (Epoch 4 / 20) train acc: 0.310000; val_acc: 0.163000
# (Iteration 5 / 20) loss: 2.078692
# (Epoch 5 / 20) train acc: 0.310000; val_acc: 0.159000
# (Iteration 6 / 20) loss: 1.998963
# (Epoch 6 / 20) train acc: 0.330000; val_acc: 0.169000
# (Iteration 7 / 20) loss: 1.881136
# (Epoch 7 / 20) train acc: 0.400000; val_acc: 0.165000
# (Iteration 8 / 20) loss: 1.785428
# (Epoch 8 / 20) train acc: 0.360000; val_acc: 0.175000
# (Iteration 9 / 20) loss: 1.555758
# (Epoch 9 / 20) train acc: 0.440000; val_acc: 0.176000
# (Iteration 10 / 20) loss: 1.395101
# (Epoch 10 / 20) train acc: 0.490000; val_acc: 0.183000
# (Iteration 11 / 20) loss: 1.472937
# (Epoch 11 / 20) train acc: 0.550000; val_acc: 0.170000
# (Iteration 12 / 20) loss: 1.325483
# (Epoch 12 / 20) train acc: 0.610000; val_acc: 0.174000
# (Iteration 13 / 20) loss: 1.258403
# (Epoch 13 / 20) train acc: 0.640000; val_acc: 0.175000
# (Iteration 14 / 20) loss: 1.142720
# (Epoch 14 / 20) train acc: 0.700000; val_acc: 0.186000
# (Iteration 15 / 20) loss: 0.848153
# (Epoch 15 / 20) train acc: 0.730000; val_acc: 0.199000
# (Iteration 16 / 20) loss: 0.918881
# (Epoch 16 / 20) train acc: 0.740000; val_acc: 0.200000
# (Iteration 17 / 20) loss: 0.940367
# (Epoch 17 / 20) train acc: 0.800000; val_acc: 0.204000
# (Iteration 18 / 20) loss: 0.635291
# (Epoch 18 / 20) train acc: 0.860000; val_acc: 0.215000
# (Iteration 19 / 20) loss: 0.367987
# (Epoch 19 / 20) train acc: 0.860000; val_acc: 0.198000
# (Iteration 20 / 20) loss: 0.567451
# (Epoch 20 / 20) train acc: 0.860000; val_acc: 0.188000
# Testing training with 4 threads and 16 batch size
# (Iteration 1 / 120) loss: 2.302579
# (Epoch 0 / 20) train acc: 0.060000; val_acc: 0.087000
# (Iteration 2 / 120) loss: 2.398489
# (Iteration 3 / 120) loss: 2.311533
# (Iteration 4 / 120) loss: 2.244668
# (Iteration 5 / 120) loss: 2.209500
# (Iteration 6 / 120) loss: 2.346014
# (Epoch 1 / 20) train acc: 0.170000; val_acc: 0.132000
# (Iteration 7 / 120) loss: 2.132516
# (Iteration 8 / 120) loss: 2.377618
# (Iteration 9 / 120) loss: 2.380939
# (Iteration 10 / 120) loss: 2.257062
# (Iteration 11 / 120) loss: 2.280144
# (Iteration 12 / 120) loss: 2.374236
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.100000
# (Iteration 13 / 120) loss: 2.261116
# (Iteration 14 / 120) loss: 2.268344
# (Iteration 15 / 120) loss: 2.200613
# (Iteration 16 / 120) loss: 2.343895
# (Iteration 17 / 120) loss: 2.060710
# (Iteration 18 / 120) loss: 2.295072
# (Epoch 3 / 20) train acc: 0.240000; val_acc: 0.144000
# (Iteration 19 / 120) loss: 2.122388
# (Iteration 20 / 120) loss: 1.853980
# (Iteration 21 / 120) loss: 2.252944
# (Iteration 22 / 120) loss: 1.732700
# (Iteration 23 / 120) loss: 1.763102
# (Iteration 24 / 120) loss: 2.290314
# (Epoch 4 / 20) train acc: 0.310000; val_acc: 0.157000
# (Iteration 25 / 120) loss: 2.209009
# (Iteration 26 / 120) loss: 2.419888
# (Iteration 27 / 120) loss: 1.769440
# (Iteration 28 / 120) loss: 1.719593
# (Iteration 29 / 120) loss: 2.024218
# (Iteration 30 / 120) loss: 1.790584
# (Epoch 5 / 20) train acc: 0.320000; val_acc: 0.160000
# (Iteration 31 / 120) loss: 1.663742
# (Iteration 32 / 120) loss: 2.225183
# (Iteration 33 / 120) loss: 1.738098
# (Iteration 34 / 120) loss: 1.602575
# (Iteration 35 / 120) loss: 2.070616
# (Iteration 36 / 120) loss: 1.276480
# (Epoch 6 / 20) train acc: 0.380000; val_acc: 0.190000
# (Iteration 37 / 120) loss: 1.717147
# (Iteration 38 / 120) loss: 1.305121
# (Iteration 39 / 120) loss: 1.535361
# (Iteration 40 / 120) loss: 1.154349
# (Iteration 41 / 120) loss: 1.966269
# (Iteration 42 / 120) loss: 1.224179
# (Epoch 7 / 20) train acc: 0.430000; val_acc: 0.193000
# (Iteration 43 / 120) loss: 1.810222
# (Iteration 44 / 120) loss: 1.479525
# (Iteration 45 / 120) loss: 1.271253
# (Iteration 46 / 120) loss: 1.654162
# (Iteration 47 / 120) loss: 1.972338
# (Iteration 48 / 120) loss: 1.451013
# (Epoch 8 / 20) train acc: 0.490000; val_acc: 0.141000
# (Iteration 49 / 120) loss: 1.792781
# (Iteration 50 / 120) loss: 1.531938
# (Iteration 51 / 120) loss: 1.931282
# (Iteration 52 / 120) loss: 2.076454
# (Iteration 53 / 120) loss: 1.741793
# (Iteration 54 / 120) loss: 1.455346
# (Epoch 9 / 20) train acc: 0.430000; val_acc: 0.148000
# (Iteration 55 / 120) loss: 1.396526
# (Iteration 56 / 120) loss: 1.333582
# (Iteration 57 / 120) loss: 1.549038
# (Iteration 58 / 120) loss: 1.279350
# (Iteration 59 / 120) loss: 1.241802
# (Iteration 60 / 120) loss: 1.071645
# (Epoch 10 / 20) train acc: 0.470000; val_acc: 0.164000
# (Iteration 61 / 120) loss: 2.204618
# (Iteration 62 / 120) loss: 1.161328
# (Iteration 63 / 120) loss: 1.377277
# (Iteration 64 / 120) loss: 0.874125
# (Iteration 65 / 120) loss: 1.340394
# (Iteration 66 / 120) loss: 1.352763
# (Epoch 11 / 20) train acc: 0.600000; val_acc: 0.157000
# (Iteration 67 / 120) loss: 1.222094
# (Iteration 68 / 120) loss: 1.069851
# (Iteration 69 / 120) loss: 0.851902
# (Iteration 70 / 120) loss: 1.344623
# (Iteration 71 / 120) loss: 0.803694
# (Iteration 72 / 120) loss: 1.076897
# (Epoch 12 / 20) train acc: 0.630000; val_acc: 0.164000
# (Iteration 73 / 120) loss: 0.831495
# (Iteration 74 / 120) loss: 0.611043
# (Iteration 75 / 120) loss: 0.944981
# (Iteration 76 / 120) loss: 0.578855
# (Iteration 77 / 120) loss: 1.140222
# (Iteration 78 / 120) loss: 1.362774
# (Epoch 13 / 20) train acc: 0.620000; val_acc: 0.169000
# (Iteration 79 / 120) loss: 1.356270
# (Iteration 80 / 120) loss: 0.926398
# (Iteration 81 / 120) loss: 0.784572
# (Iteration 82 / 120) loss: 0.775551
# (Iteration 83 / 120) loss: 1.193202
# (Iteration 84 / 120) loss: 0.717886
# (Epoch 14 / 20) train acc: 0.670000; val_acc: 0.199000
# (Iteration 85 / 120) loss: 1.171062
# (Iteration 86 / 120) loss: 0.372141
# (Iteration 87 / 120) loss: 0.693196
# (Iteration 88 / 120) loss: 0.707508
# (Iteration 89 / 120) loss: 1.161988
# (Iteration 90 / 120) loss: 0.601219
# (Epoch 15 / 20) train acc: 0.680000; val_acc: 0.178000
# (Iteration 91 / 120) loss: 0.431663
# (Iteration 92 / 120) loss: 0.629755
# (Iteration 93 / 120) loss: 0.623846
# (Iteration 94 / 120) loss: 0.450131
# (Iteration 95 / 120) loss: 0.559552
# (Iteration 96 / 120) loss: 0.706222
# (Epoch 16 / 20) train acc: 0.770000; val_acc: 0.174000
# (Iteration 97 / 120) loss: 0.724885
# (Iteration 98 / 120) loss: 0.341769
# (Iteration 99 / 120) loss: 0.962210
# (Iteration 100 / 120) loss: 0.751317
# (Iteration 101 / 120) loss: 0.897108
# (Iteration 102 / 120) loss: 0.572538
# (Epoch 17 / 20) train acc: 0.770000; val_acc: 0.151000
# (Iteration 103 / 120) loss: 0.328667
# (Iteration 104 / 120) loss: 0.590481
# (Iteration 105 / 120) loss: 0.913065
# (Iteration 106 / 120) loss: 0.891741
# (Iteration 107 / 120) loss: 0.736677
# (Iteration 108 / 120) loss: 0.376471
# (Epoch 18 / 20) train acc: 0.780000; val_acc: 0.156000
# (Iteration 109 / 120) loss: 0.812842
# (Iteration 110 / 120) loss: 0.282539
# (Iteration 111 / 120) loss: 0.630681
# (Iteration 112 / 120) loss: 0.531363
# (Iteration 113 / 120) loss: 0.938001
# (Iteration 114 / 120) loss: 0.919918
# (Epoch 19 / 20) train acc: 0.820000; val_acc: 0.167000
# (Iteration 115 / 120) loss: 0.268173
# (Iteration 116 / 120) loss: 0.524345
# (Iteration 117 / 120) loss: 0.398115
# (Iteration 118 / 120) loss: 0.508538
# (Iteration 119 / 120) loss: 0.640727
# (Iteration 120 / 120) loss: 0.462081
# (Epoch 20 / 20) train acc: 0.810000; val_acc: 0.174000
# Testing training with 4 threads and 32 batch size
# (Iteration 1 / 60) loss: 2.302598
# (Epoch 0 / 20) train acc: 0.110000; val_acc: 0.121000
# (Iteration 2 / 60) loss: 2.350591
# (Iteration 3 / 60) loss: 2.191994
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.098000
# (Iteration 4 / 60) loss: 2.386941
# (Iteration 5 / 60) loss: 2.210619
# (Iteration 6 / 60) loss: 2.208828
# (Epoch 2 / 20) train acc: 0.270000; val_acc: 0.153000
# (Iteration 7 / 60) loss: 2.031637
# (Iteration 8 / 60) loss: 2.180689
# (Iteration 9 / 60) loss: 1.978471
# (Epoch 3 / 20) train acc: 0.290000; val_acc: 0.153000
# (Iteration 10 / 60) loss: 1.933444
# (Iteration 11 / 60) loss: 2.009223
# (Iteration 12 / 60) loss: 1.975111
# (Epoch 4 / 20) train acc: 0.330000; val_acc: 0.170000
# (Iteration 13 / 60) loss: 1.867908
# (Iteration 14 / 60) loss: 1.618002
# (Iteration 15 / 60) loss: 1.736525
# (Epoch 5 / 20) train acc: 0.370000; val_acc: 0.182000
# (Iteration 16 / 60) loss: 1.501449
# (Iteration 17 / 60) loss: 1.450878
# (Iteration 18 / 60) loss: 1.699440
# (Epoch 6 / 20) train acc: 0.440000; val_acc: 0.166000
# (Iteration 19 / 60) loss: 1.450888
# (Iteration 20 / 60) loss: 1.141738
# (Iteration 21 / 60) loss: 1.164947
# (Epoch 7 / 20) train acc: 0.570000; val_acc: 0.183000
# (Iteration 22 / 60) loss: 1.210078
# (Iteration 23 / 60) loss: 1.095935
# (Iteration 24 / 60) loss: 1.121232
# (Epoch 8 / 20) train acc: 0.710000; val_acc: 0.182000
# (Iteration 25 / 60) loss: 1.301254
# (Iteration 26 / 60) loss: 0.979763
# (Iteration 27 / 60) loss: 0.905913
# (Epoch 9 / 20) train acc: 0.750000; val_acc: 0.194000
# (Iteration 28 / 60) loss: 0.508035
# (Iteration 29 / 60) loss: 0.669270
# (Iteration 30 / 60) loss: 0.641394
# (Epoch 10 / 20) train acc: 0.810000; val_acc: 0.186000
# (Iteration 31 / 60) loss: 0.649279
# (Iteration 32 / 60) loss: 0.343057
# (Iteration 33 / 60) loss: 0.380379
# (Epoch 11 / 20) train acc: 0.910000; val_acc: 0.203000
# (Iteration 34 / 60) loss: 0.279344
# (Iteration 35 / 60) loss: 0.718278
# (Iteration 36 / 60) loss: 0.319516
# (Epoch 12 / 20) train acc: 0.900000; val_acc: 0.207000
# (Iteration 37 / 60) loss: 0.252059
# (Iteration 38 / 60) loss: 0.170469
# (Iteration 39 / 60) loss: 0.384787
# (Epoch 13 / 20) train acc: 0.950000; val_acc: 0.223000
# (Iteration 40 / 60) loss: 0.093083
# (Iteration 41 / 60) loss: 0.438345
# (Iteration 42 / 60) loss: 0.359981
# (Epoch 14 / 20) train acc: 0.950000; val_acc: 0.194000
# (Iteration 43 / 60) loss: 0.226963
# (Iteration 44 / 60) loss: 0.217505
# (Iteration 45 / 60) loss: 0.742452
# (Epoch 15 / 20) train acc: 0.890000; val_acc: 0.194000
# (Iteration 46 / 60) loss: 0.360991
# (Iteration 47 / 60) loss: 0.431239
# (Iteration 48 / 60) loss: 0.107534
# (Epoch 16 / 20) train acc: 0.930000; val_acc: 0.206000
# (Iteration 49 / 60) loss: 0.231385
# (Iteration 50 / 60) loss: 0.035738
# (Iteration 51 / 60) loss: 0.288574
# (Epoch 17 / 20) train acc: 0.900000; val_acc: 0.197000
# (Iteration 52 / 60) loss: 0.273840
# (Iteration 53 / 60) loss: 0.693136
# (Iteration 54 / 60) loss: 0.120379
# (Epoch 18 / 20) train acc: 0.980000; val_acc: 0.188000
# (Iteration 55 / 60) loss: 0.077303
# (Iteration 56 / 60) loss: 0.326722
# (Iteration 57 / 60) loss: 0.073666
# (Epoch 19 / 20) train acc: 0.970000; val_acc: 0.183000
# (Iteration 58 / 60) loss: 0.333270
# (Iteration 59 / 60) loss: 0.061962
# (Iteration 60 / 60) loss: 0.069920
# (Epoch 20 / 20) train acc: 0.980000; val_acc: 0.178000
# Testing training with 4 threads and 64 batch size
# (Iteration 1 / 20) loss: 2.302606
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.119000
# (Iteration 2 / 20) loss: 2.293768
# (Epoch 2 / 20) train acc: 0.220000; val_acc: 0.130000
# (Iteration 3 / 20) loss: 2.212615
# (Epoch 3 / 20) train acc: 0.220000; val_acc: 0.139000
# (Iteration 4 / 20) loss: 2.120201
# (Epoch 4 / 20) train acc: 0.310000; val_acc: 0.163000
# (Iteration 5 / 20) loss: 2.078701
# (Epoch 5 / 20) train acc: 0.310000; val_acc: 0.159000
# (Iteration 6 / 20) loss: 1.998972
# (Epoch 6 / 20) train acc: 0.330000; val_acc: 0.169000
# (Iteration 7 / 20) loss: 1.881122
# (Epoch 7 / 20) train acc: 0.400000; val_acc: 0.165000
# (Iteration 8 / 20) loss: 1.785458
# (Epoch 8 / 20) train acc: 0.360000; val_acc: 0.175000
# (Iteration 9 / 20) loss: 1.555813
# (Epoch 9 / 20) train acc: 0.440000; val_acc: 0.176000
# (Iteration 10 / 20) loss: 1.394989
# (Epoch 10 / 20) train acc: 0.490000; val_acc: 0.183000
# (Iteration 11 / 20) loss: 1.472928
# (Epoch 11 / 20) train acc: 0.550000; val_acc: 0.170000
# (Iteration 12 / 20) loss: 1.325455
# (Epoch 12 / 20) train acc: 0.610000; val_acc: 0.174000
# (Iteration 13 / 20) loss: 1.258503
# (Epoch 13 / 20) train acc: 0.640000; val_acc: 0.175000
# (Iteration 14 / 20) loss: 1.142822
# (Epoch 14 / 20) train acc: 0.700000; val_acc: 0.186000
# (Iteration 15 / 20) loss: 0.848264
# (Epoch 15 / 20) train acc: 0.730000; val_acc: 0.200000
# (Iteration 16 / 20) loss: 0.919899
# (Epoch 16 / 20) train acc: 0.740000; val_acc: 0.200000
# (Iteration 17 / 20) loss: 0.940502
# (Epoch 17 / 20) train acc: 0.800000; val_acc: 0.204000
# (Iteration 18 / 20) loss: 0.634935
# (Epoch 18 / 20) train acc: 0.860000; val_acc: 0.214000
# (Iteration 19 / 20) loss: 0.371393
# (Epoch 19 / 20) train acc: 0.860000; val_acc: 0.200000
# (Iteration 20 / 20) loss: 0.568781
# (Epoch 20 / 20) train acc: 0.840000; val_acc: 0.185000
# Testing training with 8 threads and 16 batch size
# (Iteration 1 / 120) loss: 2.302579
# (Epoch 0 / 20) train acc: 0.060000; val_acc: 0.087000
# (Iteration 2 / 120) loss: 2.398489
# (Iteration 3 / 120) loss: 2.311533
# (Iteration 4 / 120) loss: 2.244668
# (Iteration 5 / 120) loss: 2.209500
# (Iteration 6 / 120) loss: 2.346014
# (Epoch 1 / 20) train acc: 0.170000; val_acc: 0.132000
# (Iteration 7 / 120) loss: 2.132516
# (Iteration 8 / 120) loss: 2.377618
# (Iteration 9 / 120) loss: 2.380939
# (Iteration 10 / 120) loss: 2.257062
# (Iteration 11 / 120) loss: 2.280144
# (Iteration 12 / 120) loss: 2.374236
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.100000
# (Iteration 13 / 120) loss: 2.261116
# (Iteration 14 / 120) loss: 2.268344
# (Iteration 15 / 120) loss: 2.200613
# (Iteration 16 / 120) loss: 2.343895
# (Iteration 17 / 120) loss: 2.060710
# (Iteration 18 / 120) loss: 2.295072
# (Epoch 3 / 20) train acc: 0.240000; val_acc: 0.144000
# (Iteration 19 / 120) loss: 2.122388
# (Iteration 20 / 120) loss: 1.853980
# (Iteration 21 / 120) loss: 2.252944
# (Iteration 22 / 120) loss: 1.732701
# (Iteration 23 / 120) loss: 1.763102
# (Iteration 24 / 120) loss: 2.290313
# (Epoch 4 / 20) train acc: 0.310000; val_acc: 0.157000
# (Iteration 25 / 120) loss: 2.209008
# (Iteration 26 / 120) loss: 2.419888
# (Iteration 27 / 120) loss: 1.769442
# (Iteration 28 / 120) loss: 1.719592
# (Iteration 29 / 120) loss: 2.024220
# (Iteration 30 / 120) loss: 1.790584
# (Epoch 5 / 20) train acc: 0.320000; val_acc: 0.160000
# (Iteration 31 / 120) loss: 1.663741
# (Iteration 32 / 120) loss: 2.225182
# (Iteration 33 / 120) loss: 1.738101
# (Iteration 34 / 120) loss: 1.602576
# (Iteration 35 / 120) loss: 2.070618
# (Iteration 36 / 120) loss: 1.276486
# (Epoch 6 / 20) train acc: 0.380000; val_acc: 0.190000
# (Iteration 37 / 120) loss: 1.717148
# (Iteration 38 / 120) loss: 1.305122
# (Iteration 39 / 120) loss: 1.535361
# (Iteration 40 / 120) loss: 1.154350
# (Iteration 41 / 120) loss: 1.966265
# (Iteration 42 / 120) loss: 1.225774
# (Epoch 7 / 20) train acc: 0.440000; val_acc: 0.193000
# (Iteration 43 / 120) loss: 1.798166
# (Iteration 44 / 120) loss: 1.488903
# (Iteration 45 / 120) loss: 1.272315
# (Iteration 46 / 120) loss: 1.651568
# (Iteration 47 / 120) loss: 1.971393
# (Iteration 48 / 120) loss: 1.445937
# (Epoch 8 / 20) train acc: 0.500000; val_acc: 0.142000
# (Iteration 49 / 120) loss: 1.773738
# (Iteration 50 / 120) loss: 1.538129
# (Iteration 51 / 120) loss: 1.922915
# (Iteration 52 / 120) loss: 2.074411
# (Iteration 53 / 120) loss: 1.727637
# (Iteration 54 / 120) loss: 1.451677
# (Epoch 9 / 20) train acc: 0.440000; val_acc: 0.148000
# (Iteration 55 / 120) loss: 1.406182
# (Iteration 56 / 120) loss: 1.336789
# (Iteration 57 / 120) loss: 1.548115
# (Iteration 58 / 120) loss: 1.290315
# (Iteration 59 / 120) loss: 1.268776
# (Iteration 60 / 120) loss: 1.091905
# (Epoch 10 / 20) train acc: 0.450000; val_acc: 0.171000
# (Iteration 61 / 120) loss: 2.234668
# (Iteration 62 / 120) loss: 1.190494
# (Iteration 63 / 120) loss: 1.389481
# (Iteration 64 / 120) loss: 0.895494
# (Iteration 65 / 120) loss: 1.335310
# (Iteration 66 / 120) loss: 1.312121
# (Epoch 11 / 20) train acc: 0.580000; val_acc: 0.152000
# (Iteration 67 / 120) loss: 1.241069
# (Iteration 68 / 120) loss: 1.068979
# (Iteration 69 / 120) loss: 1.026968
# (Iteration 70 / 120) loss: 1.389589
# (Iteration 71 / 120) loss: 0.822812
# (Iteration 72 / 120) loss: 1.036792
# (Epoch 12 / 20) train acc: 0.630000; val_acc: 0.170000
# (Iteration 73 / 120) loss: 0.840311
# (Iteration 74 / 120) loss: 0.664186
# (Iteration 75 / 120) loss: 0.816881
# (Iteration 76 / 120) loss: 0.636343
# (Iteration 77 / 120) loss: 1.188480
# (Iteration 78 / 120) loss: 1.369442
# (Epoch 13 / 20) train acc: 0.650000; val_acc: 0.163000
# (Iteration 79 / 120) loss: 1.348968
# (Iteration 80 / 120) loss: 0.897268
# (Iteration 81 / 120) loss: 0.792802
# (Iteration 82 / 120) loss: 0.724435
# (Iteration 83 / 120) loss: 1.227749
# (Iteration 84 / 120) loss: 0.755785
# (Epoch 14 / 20) train acc: 0.680000; val_acc: 0.175000
# (Iteration 85 / 120) loss: 1.009608
# (Iteration 86 / 120) loss: 0.277334
# (Iteration 87 / 120) loss: 0.601540
# (Iteration 88 / 120) loss: 0.797225
# (Iteration 89 / 120) loss: 1.186028
# (Iteration 90 / 120) loss: 0.419794
# (Epoch 15 / 20) train acc: 0.710000; val_acc: 0.173000
# (Iteration 91 / 120) loss: 0.463591
# (Iteration 92 / 120) loss: 0.622712
# (Iteration 93 / 120) loss: 0.607628
# (Iteration 94 / 120) loss: 0.553062
# (Iteration 95 / 120) loss: 0.641293
# (Iteration 96 / 120) loss: 0.837997
# (Epoch 16 / 20) train acc: 0.730000; val_acc: 0.174000
# (Iteration 97 / 120) loss: 0.645525
# (Iteration 98 / 120) loss: 0.382776
# (Iteration 99 / 120) loss: 0.949268
# (Iteration 100 / 120) loss: 0.742480
# (Iteration 101 / 120) loss: 0.848817
# (Iteration 102 / 120) loss: 0.428532
# (Epoch 17 / 20) train acc: 0.770000; val_acc: 0.177000
# (Iteration 103 / 120) loss: 0.479244
# (Iteration 104 / 120) loss: 0.608336
# (Iteration 105 / 120) loss: 0.759971
# (Iteration 106 / 120) loss: 0.753778
# (Iteration 107 / 120) loss: 0.451032
# (Iteration 108 / 120) loss: 0.231513
# (Epoch 18 / 20) train acc: 0.830000; val_acc: 0.171000
# (Iteration 109 / 120) loss: 0.457401
# (Iteration 110 / 120) loss: 0.318492
# (Iteration 111 / 120) loss: 0.573026
# (Iteration 112 / 120) loss: 0.342761
# (Iteration 113 / 120) loss: 0.626298
# (Iteration 114 / 120) loss: 0.782105
# (Epoch 19 / 20) train acc: 0.840000; val_acc: 0.179000
# (Iteration 115 / 120) loss: 0.356183
# (Iteration 116 / 120) loss: 0.680075
# (Iteration 117 / 120) loss: 0.366361
# (Iteration 118 / 120) loss: 0.542066
# (Iteration 119 / 120) loss: 0.431704
# (Iteration 120 / 120) loss: 0.310543
# (Epoch 20 / 20) train acc: 0.830000; val_acc: 0.189000
# Testing training with 8 threads and 32 batch size
# (Iteration 1 / 60) loss: 2.302598
# (Epoch 0 / 20) train acc: 0.110000; val_acc: 0.121000
# (Iteration 2 / 60) loss: 2.350591
# (Iteration 3 / 60) loss: 2.191994
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.098000
# (Iteration 4 / 60) loss: 2.386941
# (Iteration 5 / 60) loss: 2.210619
# (Iteration 6 / 60) loss: 2.208828
# (Epoch 2 / 20) train acc: 0.270000; val_acc: 0.153000
# (Iteration 7 / 60) loss: 2.031637
# (Iteration 8 / 60) loss: 2.180689
# (Iteration 9 / 60) loss: 1.978471
# (Epoch 3 / 20) train acc: 0.290000; val_acc: 0.153000
# (Iteration 10 / 60) loss: 1.933444
# (Iteration 11 / 60) loss: 2.009223
# (Iteration 12 / 60) loss: 1.975111
# (Epoch 4 / 20) train acc: 0.330000; val_acc: 0.170000
# (Iteration 13 / 60) loss: 1.867908
# (Iteration 14 / 60) loss: 1.618002
# (Iteration 15 / 60) loss: 1.736525
# (Epoch 5 / 20) train acc: 0.370000; val_acc: 0.182000
# (Iteration 16 / 60) loss: 1.501449
# (Iteration 17 / 60) loss: 1.450878
# (Iteration 18 / 60) loss: 1.699440
# (Epoch 6 / 20) train acc: 0.440000; val_acc: 0.166000
# (Iteration 19 / 60) loss: 1.450888
# (Iteration 20 / 60) loss: 1.141737
# (Iteration 21 / 60) loss: 1.164946
# (Epoch 7 / 20) train acc: 0.570000; val_acc: 0.183000
# (Iteration 22 / 60) loss: 1.210078
# (Iteration 23 / 60) loss: 1.095935
# (Iteration 24 / 60) loss: 1.121224
# (Epoch 8 / 20) train acc: 0.710000; val_acc: 0.182000
# (Iteration 25 / 60) loss: 1.301253
# (Iteration 26 / 60) loss: 0.979761
# (Iteration 27 / 60) loss: 0.905909
# (Epoch 9 / 20) train acc: 0.750000; val_acc: 0.194000
# (Iteration 28 / 60) loss: 0.508028
# (Iteration 29 / 60) loss: 0.669269
# (Iteration 30 / 60) loss: 0.641379
# (Epoch 10 / 20) train acc: 0.810000; val_acc: 0.186000
# (Iteration 31 / 60) loss: 0.649274
# (Iteration 32 / 60) loss: 0.343054
# (Iteration 33 / 60) loss: 0.380379
# (Epoch 11 / 20) train acc: 0.910000; val_acc: 0.203000
# (Iteration 34 / 60) loss: 0.279343
# (Iteration 35 / 60) loss: 0.718265
# (Iteration 36 / 60) loss: 0.319523
# (Epoch 12 / 20) train acc: 0.900000; val_acc: 0.207000
# (Iteration 37 / 60) loss: 0.252060
# (Iteration 38 / 60) loss: 0.170461
# (Iteration 39 / 60) loss: 0.384782
# (Epoch 13 / 20) train acc: 0.950000; val_acc: 0.223000
# (Iteration 40 / 60) loss: 0.093081
# (Iteration 41 / 60) loss: 0.438386
# (Iteration 42 / 60) loss: 0.359965
# (Epoch 14 / 20) train acc: 0.950000; val_acc: 0.194000
# (Iteration 43 / 60) loss: 0.226969
# (Iteration 44 / 60) loss: 0.217514
# (Iteration 45 / 60) loss: 0.742424
# (Epoch 15 / 20) train acc: 0.890000; val_acc: 0.194000
# (Iteration 46 / 60) loss: 0.361054
# (Iteration 47 / 60) loss: 0.431302
# (Iteration 48 / 60) loss: 0.107495
# (Epoch 16 / 20) train acc: 0.930000; val_acc: 0.206000
# (Iteration 49 / 60) loss: 0.231221
# (Iteration 50 / 60) loss: 0.035794
# (Iteration 51 / 60) loss: 0.288593
# (Epoch 17 / 20) train acc: 0.900000; val_acc: 0.197000
# (Iteration 52 / 60) loss: 0.273732
# (Iteration 53 / 60) loss: 0.692957
# (Iteration 54 / 60) loss: 0.120219
# (Epoch 18 / 20) train acc: 0.980000; val_acc: 0.188000
# (Iteration 55 / 60) loss: 0.077220
# (Iteration 56 / 60) loss: 0.326566
# (Iteration 57 / 60) loss: 0.073636
# (Epoch 19 / 20) train acc: 0.970000; val_acc: 0.183000
# (Iteration 58 / 60) loss: 0.333407
# (Iteration 59 / 60) loss: 0.061887
# (Iteration 60 / 60) loss: 0.069883
# (Epoch 20 / 20) train acc: 0.980000; val_acc: 0.178000
# Testing training with 8 threads and 64 batch size
# (Iteration 1 / 20) loss: 2.302606
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.119000
# (Iteration 2 / 20) loss: 2.293768
# (Epoch 2 / 20) train acc: 0.220000; val_acc: 0.130000
# (Iteration 3 / 20) loss: 2.212615
# (Epoch 3 / 20) train acc: 0.220000; val_acc: 0.139000
# (Iteration 4 / 20) loss: 2.120203
# (Epoch 4 / 20) train acc: 0.310000; val_acc: 0.163000
# (Iteration 5 / 20) loss: 2.078688
# (Epoch 5 / 20) train acc: 0.310000; val_acc: 0.159000
# (Iteration 6 / 20) loss: 1.998959
# (Epoch 6 / 20) train acc: 0.330000; val_acc: 0.169000
# (Iteration 7 / 20) loss: 1.881142
# (Epoch 7 / 20) train acc: 0.400000; val_acc: 0.165000
# (Iteration 8 / 20) loss: 1.785389
# (Epoch 8 / 20) train acc: 0.360000; val_acc: 0.175000
# (Iteration 9 / 20) loss: 1.555729
# (Epoch 9 / 20) train acc: 0.440000; val_acc: 0.176000
# (Iteration 10 / 20) loss: 1.395156
# (Epoch 10 / 20) train acc: 0.490000; val_acc: 0.183000
# (Iteration 11 / 20) loss: 1.473020
# (Epoch 11 / 20) train acc: 0.550000; val_acc: 0.170000
# (Iteration 12 / 20) loss: 1.325497
# (Epoch 12 / 20) train acc: 0.610000; val_acc: 0.173000
# (Iteration 13 / 20) loss: 1.258479
# (Epoch 13 / 20) train acc: 0.640000; val_acc: 0.175000
# (Iteration 14 / 20) loss: 1.142776
# (Epoch 14 / 20) train acc: 0.700000; val_acc: 0.186000
# (Iteration 15 / 20) loss: 0.848269
# (Epoch 15 / 20) train acc: 0.730000; val_acc: 0.199000
# (Iteration 16 / 20) loss: 0.918969
# (Epoch 16 / 20) train acc: 0.740000; val_acc: 0.200000
# (Iteration 17 / 20) loss: 0.940442
# (Epoch 17 / 20) train acc: 0.800000; val_acc: 0.204000
# (Iteration 18 / 20) loss: 0.635211
# (Epoch 18 / 20) train acc: 0.860000; val_acc: 0.215000
# (Iteration 19 / 20) loss: 0.368118
# (Epoch 19 / 20) train acc: 0.860000; val_acc: 0.198000
# (Iteration 20 / 20) loss: 0.567478
# (Epoch 20 / 20) train acc: 0.860000; val_acc: 0.188000
# Testing training with 16 threads and 16 batch size
# (Iteration 1 / 120) loss: 2.302579
# (Epoch 0 / 20) train acc: 0.060000; val_acc: 0.087000
# (Iteration 2 / 120) loss: 2.398489
# (Iteration 3 / 120) loss: 2.311533
# (Iteration 4 / 120) loss: 2.244668
# (Iteration 5 / 120) loss: 2.209500
# (Iteration 6 / 120) loss: 2.346014
# (Epoch 1 / 20) train acc: 0.170000; val_acc: 0.132000
# (Iteration 7 / 120) loss: 2.132516
# (Iteration 8 / 120) loss: 2.377615
# (Iteration 9 / 120) loss: 2.380938
# (Iteration 10 / 120) loss: 2.257062
# (Iteration 11 / 120) loss: 2.280142
# (Iteration 12 / 120) loss: 2.374242
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.100000
# (Iteration 13 / 120) loss: 2.261112
# (Iteration 14 / 120) loss: 2.268344
# (Iteration 15 / 120) loss: 2.200625
# (Iteration 16 / 120) loss: 2.343851
# (Iteration 17 / 120) loss: 2.060668
# (Iteration 18 / 120) loss: 2.295061
# (Epoch 3 / 20) train acc: 0.240000; val_acc: 0.144000
# (Iteration 19 / 120) loss: 2.122410
# (Iteration 20 / 120) loss: 1.853952
# (Iteration 21 / 120) loss: 2.252904
# (Iteration 22 / 120) loss: 1.732645
# (Iteration 23 / 120) loss: 1.763086
# (Iteration 24 / 120) loss: 2.290330
# (Epoch 4 / 20) train acc: 0.310000; val_acc: 0.157000
# (Iteration 25 / 120) loss: 2.209045
# (Iteration 26 / 120) loss: 2.419830
# (Iteration 27 / 120) loss: 1.769373
# (Iteration 28 / 120) loss: 1.719615
# (Iteration 29 / 120) loss: 2.024243
# (Iteration 30 / 120) loss: 1.790538
# (Epoch 5 / 20) train acc: 0.320000; val_acc: 0.160000
# (Iteration 31 / 120) loss: 1.663757
# (Iteration 32 / 120) loss: 2.225158
# (Iteration 33 / 120) loss: 1.737976
# (Iteration 34 / 120) loss: 1.602564
# (Iteration 35 / 120) loss: 2.070689
# (Iteration 36 / 120) loss: 1.276349
# (Epoch 6 / 20) train acc: 0.380000; val_acc: 0.190000
# (Iteration 37 / 120) loss: 1.717172
# (Iteration 38 / 120) loss: 1.305017
# (Iteration 39 / 120) loss: 1.535652
# (Iteration 40 / 120) loss: 1.154484
# (Iteration 41 / 120) loss: 1.965991
# (Iteration 42 / 120) loss: 1.224262
# (Epoch 7 / 20) train acc: 0.430000; val_acc: 0.193000
# (Iteration 43 / 120) loss: 1.809502
# (Iteration 44 / 120) loss: 1.479792
# (Iteration 45 / 120) loss: 1.271471
# (Iteration 46 / 120) loss: 1.653910
# (Iteration 47 / 120) loss: 1.972227
# (Iteration 48 / 120) loss: 1.451324
# (Epoch 8 / 20) train acc: 0.490000; val_acc: 0.142000
# (Iteration 49 / 120) loss: 1.793731
# (Iteration 50 / 120) loss: 1.531166
# (Iteration 51 / 120) loss: 1.931355
# (Iteration 52 / 120) loss: 2.078911
# (Iteration 53 / 120) loss: 1.740955
# (Iteration 54 / 120) loss: 1.453204
# (Epoch 9 / 20) train acc: 0.440000; val_acc: 0.146000
# (Iteration 55 / 120) loss: 1.396664
# (Iteration 56 / 120) loss: 1.341956
# (Iteration 57 / 120) loss: 1.550915
# (Iteration 58 / 120) loss: 1.277483
# (Iteration 59 / 120) loss: 1.263754
# (Iteration 60 / 120) loss: 1.085959
# (Epoch 10 / 20) train acc: 0.430000; val_acc: 0.168000
# (Iteration 61 / 120) loss: 2.267925
# (Iteration 62 / 120) loss: 1.170033
# (Iteration 63 / 120) loss: 1.380710
# (Iteration 64 / 120) loss: 0.884295
# (Iteration 65 / 120) loss: 1.355334
# (Iteration 66 / 120) loss: 1.373706
# (Epoch 11 / 20) train acc: 0.570000; val_acc: 0.156000
# (Iteration 67 / 120) loss: 1.243919
# (Iteration 68 / 120) loss: 1.086149
# (Iteration 69 / 120) loss: 0.892847
# (Iteration 70 / 120) loss: 1.377686
# (Iteration 71 / 120) loss: 0.811672
# (Iteration 72 / 120) loss: 1.090485
# (Epoch 12 / 20) train acc: 0.620000; val_acc: 0.167000
# (Iteration 73 / 120) loss: 0.843712
# (Iteration 74 / 120) loss: 0.605374
# (Iteration 75 / 120) loss: 0.976669
# (Iteration 76 / 120) loss: 0.596235
# (Iteration 77 / 120) loss: 1.187632
# (Iteration 78 / 120) loss: 1.380848
# (Epoch 13 / 20) train acc: 0.610000; val_acc: 0.165000
# (Iteration 79 / 120) loss: 1.339314
# (Iteration 80 / 120) loss: 0.932538
# (Iteration 81 / 120) loss: 0.850175
# (Iteration 82 / 120) loss: 0.774583
# (Iteration 83 / 120) loss: 1.068364
# (Iteration 84 / 120) loss: 0.706469
# (Epoch 14 / 20) train acc: 0.690000; val_acc: 0.198000
# (Iteration 85 / 120) loss: 1.221420
# (Iteration 86 / 120) loss: 0.443799
# (Iteration 87 / 120) loss: 0.656804
# (Iteration 88 / 120) loss: 0.716958
# (Iteration 89 / 120) loss: 1.006734
# (Iteration 90 / 120) loss: 0.582075
# (Epoch 15 / 20) train acc: 0.760000; val_acc: 0.179000
# (Iteration 91 / 120) loss: 0.406865
# (Iteration 92 / 120) loss: 0.634049
# (Iteration 93 / 120) loss: 0.668204
# (Iteration 94 / 120) loss: 0.459664
# (Iteration 95 / 120) loss: 0.381104
# (Iteration 96 / 120) loss: 0.748276
# (Epoch 16 / 20) train acc: 0.740000; val_acc: 0.180000
# (Iteration 97 / 120) loss: 0.702436
# (Iteration 98 / 120) loss: 0.393303
# (Iteration 99 / 120) loss: 0.925272
# (Iteration 100 / 120) loss: 0.767222
# (Iteration 101 / 120) loss: 0.896868
# (Iteration 102 / 120) loss: 0.831982
# (Epoch 17 / 20) train acc: 0.740000; val_acc: 0.147000
# (Iteration 103 / 120) loss: 0.250186
# (Iteration 104 / 120) loss: 0.471275
# (Iteration 105 / 120) loss: 0.867975
# (Iteration 106 / 120) loss: 0.983769
# (Iteration 107 / 120) loss: 0.497028
# (Iteration 108 / 120) loss: 0.416864
# (Epoch 18 / 20) train acc: 0.690000; val_acc: 0.157000
# (Iteration 109 / 120) loss: 1.321444
# (Iteration 110 / 120) loss: 0.444008
# (Iteration 111 / 120) loss: 0.563615
# (Iteration 112 / 120) loss: 0.548585
# (Iteration 113 / 120) loss: 0.466025
# (Iteration 114 / 120) loss: 0.879531
# (Epoch 19 / 20) train acc: 0.710000; val_acc: 0.183000
# (Iteration 115 / 120) loss: 0.437842
# (Iteration 116 / 120) loss: 0.510095
# (Iteration 117 / 120) loss: 0.891206
# (Iteration 118 / 120) loss: 0.441585
# (Iteration 119 / 120) loss: 1.070556
# (Iteration 120 / 120) loss: 0.427080
# (Epoch 20 / 20) train acc: 0.770000; val_acc: 0.175000
# Testing training with 16 threads and 32 batch size
# (Iteration 1 / 60) loss: 2.302598
# (Epoch 0 / 20) train acc: 0.110000; val_acc: 0.121000
# (Iteration 2 / 60) loss: 2.350591
# (Iteration 3 / 60) loss: 2.191995
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.098000
# (Iteration 4 / 60) loss: 2.386932
# (Iteration 5 / 60) loss: 2.210626
# (Iteration 6 / 60) loss: 2.208828
# (Epoch 2 / 20) train acc: 0.270000; val_acc: 0.153000
# (Iteration 7 / 60) loss: 2.031610
# (Iteration 8 / 60) loss: 2.180714
# (Iteration 9 / 60) loss: 1.978459
# (Epoch 3 / 20) train acc: 0.290000; val_acc: 0.153000
# (Iteration 10 / 60) loss: 1.933452
# (Iteration 11 / 60) loss: 2.009227
# (Iteration 12 / 60) loss: 1.973597
# (Epoch 4 / 20) train acc: 0.330000; val_acc: 0.171000
# (Iteration 13 / 60) loss: 1.868189
# (Iteration 14 / 60) loss: 1.617902
# (Iteration 15 / 60) loss: 1.736994
# (Epoch 5 / 20) train acc: 0.370000; val_acc: 0.182000
# (Iteration 16 / 60) loss: 1.502586
# (Iteration 17 / 60) loss: 1.454197
# (Iteration 18 / 60) loss: 1.683652
# (Epoch 6 / 20) train acc: 0.440000; val_acc: 0.169000
# (Iteration 19 / 60) loss: 1.451953
# (Iteration 20 / 60) loss: 1.147139
# (Iteration 21 / 60) loss: 1.151503
# (Epoch 7 / 20) train acc: 0.570000; val_acc: 0.187000
# (Iteration 22 / 60) loss: 1.211665
# (Iteration 23 / 60) loss: 1.097468
# (Iteration 24 / 60) loss: 1.086705
# (Epoch 8 / 20) train acc: 0.700000; val_acc: 0.183000
# (Iteration 25 / 60) loss: 1.311194
# (Iteration 26 / 60) loss: 0.915430
# (Iteration 27 / 60) loss: 0.950375
# (Epoch 9 / 20) train acc: 0.750000; val_acc: 0.195000
# (Iteration 28 / 60) loss: 0.493208
# (Iteration 29 / 60) loss: 0.660309
# (Iteration 30 / 60) loss: 0.660176
# (Epoch 10 / 20) train acc: 0.790000; val_acc: 0.193000
# (Iteration 31 / 60) loss: 0.650530
# (Iteration 32 / 60) loss: 0.351400
# (Iteration 33 / 60) loss: 0.360972
# (Epoch 11 / 20) train acc: 0.890000; val_acc: 0.192000
# (Iteration 34 / 60) loss: 0.272657
# (Iteration 35 / 60) loss: 0.737049
# (Iteration 36 / 60) loss: 0.310191
# (Epoch 12 / 20) train acc: 0.890000; val_acc: 0.205000
# (Iteration 37 / 60) loss: 0.249864
# (Iteration 38 / 60) loss: 0.217675
# (Iteration 39 / 60) loss: 0.390891
# (Epoch 13 / 20) train acc: 0.950000; val_acc: 0.212000
# (Iteration 40 / 60) loss: 0.170205
# (Iteration 41 / 60) loss: 0.410064
# (Iteration 42 / 60) loss: 0.349890
# (Epoch 14 / 20) train acc: 0.950000; val_acc: 0.205000
# (Iteration 43 / 60) loss: 0.157870
# (Iteration 44 / 60) loss: 0.243761
# (Iteration 45 / 60) loss: 0.727499
# (Epoch 15 / 20) train acc: 0.910000; val_acc: 0.210000
# (Iteration 46 / 60) loss: 0.161404
# (Iteration 47 / 60) loss: 0.375692
# (Iteration 48 / 60) loss: 0.140034
# (Epoch 16 / 20) train acc: 0.970000; val_acc: 0.225000
# (Iteration 49 / 60) loss: 0.233983
# (Iteration 50 / 60) loss: 0.091710
# (Iteration 51 / 60) loss: 0.057152
# (Epoch 17 / 20) train acc: 0.970000; val_acc: 0.195000
# (Iteration 52 / 60) loss: 0.073991
# (Iteration 53 / 60) loss: 0.460237
# (Iteration 54 / 60) loss: 0.055616
# (Epoch 18 / 20) train acc: 0.980000; val_acc: 0.182000
# (Iteration 55 / 60) loss: 0.089680
# (Iteration 56 / 60) loss: 0.215871
# (Iteration 57 / 60) loss: 0.258045
# (Epoch 19 / 20) train acc: 0.970000; val_acc: 0.189000
# (Iteration 58 / 60) loss: 0.045095
# (Iteration 59 / 60) loss: 0.157814
# (Iteration 60 / 60) loss: 0.114050
# (Epoch 20 / 20) train acc: 0.970000; val_acc: 0.206000
# Testing training with 16 threads and 64 batch size
# (Iteration 1 / 20) loss: 2.302606
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.119000
# (Iteration 2 / 20) loss: 2.293767
# (Epoch 2 / 20) train acc: 0.220000; val_acc: 0.130000
# (Iteration 3 / 20) loss: 2.212615
# (Epoch 3 / 20) train acc: 0.220000; val_acc: 0.139000
# (Iteration 4 / 20) loss: 2.120213
# (Epoch 4 / 20) train acc: 0.310000; val_acc: 0.163000
# (Iteration 5 / 20) loss: 2.078643
# (Epoch 5 / 20) train acc: 0.310000; val_acc: 0.159000
# (Iteration 6 / 20) loss: 1.998906
# (Epoch 6 / 20) train acc: 0.330000; val_acc: 0.170000
# (Iteration 7 / 20) loss: 1.881170
# (Epoch 7 / 20) train acc: 0.400000; val_acc: 0.165000
# (Iteration 8 / 20) loss: 1.785240
# (Epoch 8 / 20) train acc: 0.360000; val_acc: 0.175000
# (Iteration 9 / 20) loss: 1.555507
# (Epoch 9 / 20) train acc: 0.440000; val_acc: 0.176000
# (Iteration 10 / 20) loss: 1.395642
# (Epoch 10 / 20) train acc: 0.490000; val_acc: 0.183000
# (Iteration 11 / 20) loss: 1.473124
# (Epoch 11 / 20) train acc: 0.550000; val_acc: 0.170000
# (Iteration 12 / 20) loss: 1.325061
# (Epoch 12 / 20) train acc: 0.610000; val_acc: 0.176000
# (Iteration 13 / 20) loss: 1.256847
# (Epoch 13 / 20) train acc: 0.650000; val_acc: 0.172000
# (Iteration 14 / 20) loss: 1.143592
# (Epoch 14 / 20) train acc: 0.700000; val_acc: 0.186000
# (Iteration 15 / 20) loss: 0.848787
# (Epoch 15 / 20) train acc: 0.730000; val_acc: 0.200000
# (Iteration 16 / 20) loss: 0.920222
# (Epoch 16 / 20) train acc: 0.760000; val_acc: 0.200000
# (Iteration 17 / 20) loss: 0.946224
# (Epoch 17 / 20) train acc: 0.800000; val_acc: 0.204000
# (Iteration 18 / 20) loss: 0.634346
# (Epoch 18 / 20) train acc: 0.860000; val_acc: 0.217000
# (Iteration 19 / 20) loss: 0.366821
# (Epoch 19 / 20) train acc: 0.860000; val_acc: 0.199000
# (Iteration 20 / 20) loss: 0.561573
# (Epoch 20 / 20) train acc: 0.840000; val_acc: 0.188000

# %%
# Plot the training time for each batch size, with different lines for each number of threads
plt.figure()
for i, num_threads in enumerate(num_threads_list):
    plt.plot(batch_size_list, training_times[i, :], marker='o', label=f'{num_threads} Threads')

plt.xlabel('Batch Size')
plt.ylabel('Training Time (seconds)')
plt.title('Training Time vs. Batch Size (for different number of threads)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Train the Network
# By training the three-layer convolutional network for one epoch, you should achieve greater than 40% accuracy on the training set:

# %%
model = ThreeLayerConvNet(weight_scale=0.001, hidden_dim=500, reg=0.001)

all_data = {
   'X_train': data['X_train'].astype(np.float32),
   'y_train': data['y_train'].astype(np.int8),
   'X_val': data['X_val'].astype(np.float32),
   'y_val': data['y_val'].astype(np.int8),
}

solver = Solver(
    model,
    all_data,
    num_epochs=1,
    batch_size=50,
    update_rule='adam',
    optim_config={'learning_rate': 1e-3,},
    verbose=True,
    print_every=20
)
solver.train()
# Out:
# (Iteration 1 / 980) loss: 2.304592
# (Epoch 0 / 1) train acc: 0.113000; val_acc: 0.119000
# (Iteration 21 / 980) loss: 2.085584
# (Iteration 41 / 980) loss: 2.001988
# (Iteration 61 / 980) loss: 1.795318
# (Iteration 81 / 980) loss: 1.655118
# (Iteration 101 / 980) loss: 2.107492
# (Iteration 121 / 980) loss: 1.525760
# (Iteration 141 / 980) loss: 1.634396
# (Iteration 161 / 980) loss: 1.986066
# (Iteration 181 / 980) loss: 1.525604
# (Iteration 201 / 980) loss: 1.848267
# (Iteration 221 / 980) loss: 1.994407
# (Iteration 241 / 980) loss: 1.504660
# (Iteration 261 / 980) loss: 1.678075
# (Iteration 281 / 980) loss: 1.762845
# (Iteration 301 / 980) loss: 1.791279
# (Iteration 321 / 980) loss: 1.518900
# (Iteration 341 / 980) loss: 1.451508
# (Iteration 361 / 980) loss: 1.655723
# (Iteration 381 / 980) loss: 1.850931
# (Iteration 401 / 980) loss: 1.476554
# (Iteration 421 / 980) loss: 1.533841
# (Iteration 441 / 980) loss: 1.595188
# (Iteration 461 / 980) loss: 1.805070
# (Iteration 481 / 980) loss: 1.428111
# (Iteration 501 / 980) loss: 1.564377
# (Iteration 521 / 980) loss: 1.847494
# (Iteration 541 / 980) loss: 1.374587
# (Iteration 561 / 980) loss: 1.728436
# (Iteration 581 / 980) loss: 1.644478
# (Iteration 601 / 980) loss: 1.540146
# (Iteration 621 / 980) loss: 1.171159
# (Iteration 641 / 980) loss: 1.692088
# (Iteration 661 / 980) loss: 1.912027
# (Iteration 681 / 980) loss: 1.414367
# (Iteration 701 / 980) loss: 1.581847
# (Iteration 721 / 980) loss: 1.653532
# (Iteration 741 / 980) loss: 1.639018
# (Iteration 761 / 980) loss: 1.457060
# (Iteration 781 / 980) loss: 1.383619
# (Iteration 801 / 980) loss: 1.424873
# (Iteration 821 / 980) loss: 1.676746
# (Iteration 841 / 980) loss: 1.518808
# (Iteration 861 / 980) loss: 1.468083
# (Iteration 881 / 980) loss: 1.467734
# (Iteration 901 / 980) loss: 1.683665
# (Iteration 921 / 980) loss: 1.580759
# (Iteration 941 / 980) loss: 1.708516
# (Iteration 961 / 980) loss: 1.560878
# (Epoch 1 / 1) train acc: 0.449000; val_acc: 0.456000

# %%
# Print final training accuracy.
print(
    "Full data training accuracy:",
    solver.check_accuracy(data['X_train'].astype(np.float32), data['y_train'])
)
# Out:
# Full data training accuracy: 0.45753061224489794

# %%
# Print final validation accuracy.
print(
    "Full data validation accuracy:",
    solver.check_accuracy(data['X_val'].astype(np.float32), data['y_val'])
)
# Out:
# Full data validation accuracy: 0.456

# %% [markdown]
# ## Visualize Filters
# You can visualize the first-layer convolutional filters from the trained network by running the following:

# %%
from sjk012.vis_utils import visualize_grid

grid = visualize_grid(model.params['W1'].transpose(0, 2, 3, 1))
plt.imshow(grid.astype('uint8'))
plt.axis('off')
plt.gcf().set_size_inches(7,7)
plt.show()
